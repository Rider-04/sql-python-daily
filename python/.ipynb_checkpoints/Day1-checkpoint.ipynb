# %%
import mysql.connector
from mysql.connector import Error
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
# MySQL Connection
conn = mysql.connector.connect(
    host = "localhost",
    user = "root"      ,
    password = "parth004",
    database = "dummy"
)

# Employees Table
employees = pd.read_sql("SELECT * FROM employees", conn)

# Customers Table
customers = pd.read_sql("SELECT * FROM customers", conn)

# Offices Table
offices = pd.read_sql("SELECT * FROM offices", conn)

# Payments Table
payments = pd.read_sql("SELECT * FROM payments", conn)

# Orders Table
orders = pd.read_sql("SELECT * FROM orders", conn)

# Order Details Table
orderdetails = pd.read_sql("SELECT * FROM orderdetails", conn)

# Product Name Table
products = pd.read_sql("SELECT * FROM products", conn)

# Product Line Table
productlines = pd.read_sql("SELECT * FROM productlines", conn)

# Close connection
conn.close()

# %%
# Display the first 5 rows.
customers.head()
# Out:
#    customerNumber                customerName contactLastName  \
# 0             103                      bhopal         Schmitt
# 1             112          Signal Gift Stores            King
# 2             114  Australian Collectors, Co.        Ferguson
# 3             119           La Rochelle Gifts         Labrune
# 4             121          Baane Mini Imports      Bergulfsen
#
#   contactFirstName         phone                  addressLine1 addressLine2  \
# 0          Carine     40.32.2555                54, rue Royale         None
# 1             Jean    7025551838               8489 Strong St.         None
# 2            Peter  03 9520 4555             636 St Kilda Road      Level 3
# 3          Janine     40.67.8555  67, rue des Cinquante Otages         None
# 4           Jonas     07-98 9555        Erling Skakkes gate 78         None
#
#         city     state postalCode    country  salesrepemployeenumber  \
# ...

# %%
# Check the shape (rows, columns) of the products DataFrame.
customers.shape
# Out:
# (122, 13)

# %%
# Get summary statistics (describe()) of the products DataFrame.
products.describe()
# Out:
#        quantityInStock    buyPrice        MSRP
# count       110.000000  110.000000  110.000000
# mean       5046.645455   54.395182  100.438727
# std        2939.263668   22.051130   39.663649
# min          15.000000   15.910000   33.190000
# 25%        2419.000000   34.180000   68.907500
# 50%        5437.500000   53.915000   98.300000
# 75%        7599.750000   68.675000  122.850000
# max        9997.000000  103.420000  214.300000

# %%
# Check for missing values in the customers DataFrame.
customers.isna().sum()
# Out:
# customerNumber              0
# customerName                0
# contactLastName             0
# contactFirstName            0
# phone                       0
# addressLine1                0
# addressLine2              100
# city                        0
# state                      73
# postalCode                  7
# country                     0
# salesrepemployeenumber     22
# creditLimit                 0
# dtype: int64

# %%
# Select only the productName and MSRP columns.
products[["productName","MSRP"]]
# Out:
#                                productName    MSRP
# 0    1969 Harley Davidson Ultimate Chopper   95.70
# 1                 1952 Alpine Renault 1300  214.30
# 2                    1996 Moto Guzzi 1100i  118.94
# 3     2003 Harley-Davidson Eagle Drag Bike  193.66
# 4                      1972 Alfa Romeo GTA  136.00
# ..                                     ...     ...
# 105                            The Titanic  100.17
# 106                         The Queen Mary   99.31
# 107              American Airlines: MD-11S   74.03
# 108                       Boeing X-32A JSF   49.66
# 109                             Pont Yacht   54.60
#
# [110 rows x 2 columns]

# %%
# Filter products where quantityInStock < 1000.
products[products['quantityInStock']>1000]
# Out:
#     productCode                            productName   productLine  \
# 0      S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 1      S10_1949               1952 Alpine Renault 1300  Classic Cars
# 2      S10_2016                  1996 Moto Guzzi 1100i   Motorcycles
# 3      S10_4698   2003 Harley-Davidson Eagle Drag Bike   Motorcycles
# 4      S10_4757                    1972 Alfa Romeo GTA  Classic Cars
# ..          ...                                    ...           ...
# 103   S700_2834                          ATA: B757-300        Planes
# 105   S700_3505                            The Titanic         Ships
# 106   S700_3962                         The Queen Mary         Ships
# 107   S700_4002              American Airlines: MD-11S        Planes
# 108    S72_1253                       Boeing X-32A JSF        Planes
#
#     productScale              productVendor  \
# 0           1:10            Min Lin Diecast
# 1           1:10    Classic Metal Creations
# ...

# %%
# Sort the products DataFrame by buyPrice descending.
products.sort_values(by='buyPrice', ascending=False)
# Out:
#    productCode                                productName   productLine  \
# 5     S10_4962                     1962 LanciaA Delta 16V  Classic Cars
# 25    S18_2238             1998 Chrysler Plymouth Prowler  Classic Cars
# 1     S10_1949                   1952 Alpine Renault 1300  Classic Cars
# 77    S24_3856                    1956 Porsche 356A Coupe  Classic Cars
# 7     S12_1108                          2001 Ferrari Enzo  Classic Cars
# ..         ...                                        ...           ...
# 60    S24_1937                1939 Chevrolet Deluxe Coupe  Vintage Cars
# 79    S24_3969           1936 Mercedes Benz 500k Roadster  Vintage Cars
# 63    S24_2022  1938 Cadillac V-16 Presidential Limousine  Vintage Cars
# 70    S24_2972                    1982 Lamborghini Diablo  Classic Cars
# 67    S24_2840        1958 Chevy Corvette Limited Edition  Classic Cars
#
#    productScale             productVendor  \
# 5          1:10       Second Gear Diecast
# ...

# %%
# Find the mean, median, and mode of MSRP in products.
print(products['MSRP'].mean())
print(products['MSRP'].median())
print(products['MSRP'].mode())
sum=0
count=0
for i in products['MSRP']:
    sum=sum+i
    count=count+1
mean=sum/count
print(mean)
# smsrp=products['MSRP'].sort_values
# print(smsrp)
# if count % 2 == 0:
#     median = (smsrp.iloc[count//2 - 1] + smsrp.iloc[count//2]) / 2
# else:
#     median = smsrp.iloc[count//2]
# Out:
# 100.43872727272728
# 98.3
# 0     50.31
# 1    117.44
# Name: MSRP, dtype: float64
# 100.43872727272729

# %%
# Create a new column profit = MSRP - buyPrice in the products DataFrame.
for i in range(len(products)):
    products['profit']=products['MSRP']-products['buyPrice']
products
# Out:
#     productCode                            productName   productLine  \
# 0      S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 1      S10_1949               1952 Alpine Renault 1300  Classic Cars
# 2      S10_2016                  1996 Moto Guzzi 1100i   Motorcycles
# 3      S10_4698   2003 Harley-Davidson Eagle Drag Bike   Motorcycles
# 4      S10_4757                    1972 Alfa Romeo GTA  Classic Cars
# ..          ...                                    ...           ...
# 105   S700_3505                            The Titanic         Ships
# 106   S700_3962                         The Queen Mary         Ships
# 107   S700_4002              American Airlines: MD-11S        Planes
# 108    S72_1253                       Boeing X-32A JSF        Planes
# 109    S72_3212                             Pont Yacht         Ships
#
#     productScale              productVendor  \
# 0           1:10            Min Lin Diecast
# 1           1:10    Classic Metal Creations
# ...

# %%
# Count how many unique productLine values exist.
print(products['productLine'].unique())
products['productLine'].value_counts()
# Out:
# ['Motorcycles' 'Classic Cars' 'Trucks and Buses' 'Vintage Cars' 'Planes'
#  'Ships' 'Trains']
# productLine
# Classic Cars        38
# Vintage Cars        24
# Motorcycles         13
# Planes              12
# Trucks and Buses    11
# Ships                9
# Trains               3
# Name: count, dtype: int64

# %%
# Group products by productLine and find the average MSRP for each.
products.groupby('productLine')['MSRP'].mean()
products.groupby('productLine')['MSRP'].mean()
# Out:
# productLine
# Classic Cars        118.021053
# Motorcycles          97.178462
# Planes               89.515833
# Ships                86.563333
# Trains               73.853333
# Trucks and Buses    103.183636
# Vintage Cars         87.095833
# Name: MSRP, dtype: float64

# %%
# Plot a histogram of buyPrice using matplotlib/seaborn.
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(products['buyPrice'], bins=20)
plt.xlabel('Buy Price')
plt.ylabel('Frequency')
plt.title('Distribution of Buy Price')
plt.show()

# %%
# Convert the orderDate column in orders to datetime format.
orders['orderDate'] = pd.to_datetime(orders['orderDate'])
orders
# Out:
#      orderNumber  orderDate requiredDate shippedDate      status  \
# 0          10100 2003-01-06   2003-01-13  2003-01-10     Shipped
# 1          10101 2003-01-09   2003-01-18  2003-01-11     Shipped
# 2          10102 2003-01-10   2003-01-18  2003-01-14     Shipped
# 3          10103 2003-01-29   2003-02-07  2003-02-02     Shipped
# 4          10104 2003-01-31   2003-02-09  2003-02-01     Shipped
# ..           ...        ...          ...         ...         ...
# 321        10421 2005-05-29   2005-06-06        None  In Process
# 322        10422 2005-05-30   2005-06-11        None  In Process
# 323        10423 2005-05-30   2005-06-05        None  In Process
# 324        10424 2005-05-31   2005-06-08        None  In Process
# 325        10425 2005-05-31   2005-06-07        None  In Process
#
#                                               comments  customerNumber
# 0                                                 None             363
# ...

# %%
# Extract the year from orderDate and create a new column orderYear.
orders['orderYear'] = orders['orderDate'].dt.year
orders
# Out:
#      orderNumber  orderDate requiredDate shippedDate      status  \
# 0          10100 2003-01-06   2003-01-13  2003-01-10     Shipped
# 1          10101 2003-01-09   2003-01-18  2003-01-11     Shipped
# 2          10102 2003-01-10   2003-01-18  2003-01-14     Shipped
# 3          10103 2003-01-29   2003-02-07  2003-02-02     Shipped
# 4          10104 2003-01-31   2003-02-09  2003-02-01     Shipped
# ..           ...        ...          ...         ...         ...
# 321        10421 2005-05-29   2005-06-06        None  In Process
# 322        10422 2005-05-30   2005-06-11        None  In Process
# 323        10423 2005-05-30   2005-06-05        None  In Process
# 324        10424 2005-05-31   2005-06-08        None  In Process
# 325        10425 2005-05-31   2005-06-07        None  In Process
#
#                                               comments  customerNumber  \
# 0                                                 None             363
# ...

# %%
print("Year:")
print(orders['orderDate'].dt.year)

print("Month:")
print(orders['orderDate'].dt.month)

print("Day:")
print(orders['orderDate'].dt.day)

print("Day Name:")
print(orders['orderDate'].dt.day_name())

print("Weekday:")
print(orders['orderDate'].dt.weekday)
# Out:
# Year:
# 0      2003
# 1      2003
# 2      2003
# 3      2003
# 4      2003
#        ...
# 321    2005
# 322    2005
# 323    2005
# 324    2005
# 325    2005
# Name: orderDate, Length: 326, dtype: int32
# Month:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 321    5
# 322    5
# 323    5
# 324    5
# 325    5
# Name: orderDate, Length: 326, dtype: int32
# Day:
# 0       6
# 1       9
# 2      10
# 3      29
# 4      31
#        ..
# 321    29
# 322    30
# 323    30
# 324    31
# 325    31
# Name: orderDate, Length: 326, dtype: int32
# Day Name:
# 0         Monday
# 1       Thursday
# 2         Friday
# 3      Wednesday
# 4         Friday
#          ...
# 321       Sunday
# 322       Monday
# 323       Monday
# 324      Tuesday
# 325      Tuesday
# Name: orderDate, Length: 326, dtype: object
# Weekday:
# 0      0
# 1      3
# 2      4
# 3      2
# 4      4
#       ..
# 321    6
# 322    0
# 323    0
# 324    1
# 325    1
# ...

# %%
# Find the number of null values per column in the orders DataFrame.
print(orders.isnull().sum())
# Out:
# orderNumber         0
# orderDate           0
# requiredDate        0
# shippedDate        14
# status              0
# comments          246
# customerNumber      0
# orderYear           0
# dtype: int64
